# %%
import requests
from bs4 import BeautifulSoup

# %%
page = requests.get("https://www.nobroker.in/property/sale/mumbai/multiple?searchParam=...&radius=2.0&city=mumbai&locality=Indira%20Nagar,&locality=Jaya%20Nagar,&locality=Rajajinagar")

# %%
page.content
# Out:
# b'\n          <!DOCTYPE html><html lang="en"><head>\n          <meta property="fb:pages" content="794951570520699" />\n          <link rel="canonical" href="https://www.nobroker.in" />\n          \n        \n           \n          <link rel="dns-prefetch" href="//www.googletagmanager.com">\n          <link rel="dns-prefetch" href="//www.google-analytics.com">\n          <link rel="dns-prefetch" href="//assets.nobroker.in">\n          <link rel="dns-prefetch" href="//images.nobroker.in">\n          <link rel="shortcut icon" id="favicon" href="//assets.nobroker.in/static/img/favicon.png"/>\n          <link rel="apple-touch-icon" href="https://images.nobroker.in/static/img/fav64.png">\n          <meta charset="utf-8"/><meta charset="UTF-8"/>\n          <meta name="google-play-app" content="app-id=com.nobroker.app&referrer=utm_source%3Dnobroker%26utm_medium%3DmobileWeb">\n    \t    <meta name="apple-itunes-app" content="app-id=1200507100, app-argument=nobrokerapp://">\n          <meta na
# ...

# %%
soup = BeautifulSoup(page.content)
soup
# Out:
# <!DOCTYPE html>
# <html lang="en"><head>
# <meta content="794951570520699" property="fb:pages"/>
# <link href="https://www.nobroker.in" rel="canonical"/>
# <link href="//www.googletagmanager.com" rel="dns-prefetch"/>
# <link href="//www.google-analytics.com" rel="dns-prefetch"/>
# <link href="//assets.nobroker.in" rel="dns-prefetch"/>
# <link href="//images.nobroker.in" rel="dns-prefetch"/>
# <link href="//assets.nobroker.in/static/img/favicon.png" id="favicon" rel="shortcut icon"/>
# <link href="https://images.nobroker.in/static/img/fav64.png" rel="apple-touch-icon"/>
# <meta charset="utf-8"/><meta charset="utf-8"/>
# <meta content="app-id=com.nobroker.app&amp;referrer=utm_source%3Dnobroker%26utm_medium%3DmobileWeb" name="google-play-app"/>
# <meta content="app-id=1200507100, app-argument=nobrokerapp://" name="apple-itunes-app"/>
# <meta content="#fd3752" name="theme-color"/>
# ...

# %%
names = []
for i in soup.find_all('a', class_='nb__U5JyW'):
  names.append(i.text)
names[0].strip()

names
# Out:
# ['3 BHK Flat  For Sale  In La Vista In Borivali East  ',
#  '2 BHK Flat  For Sale  In Dimple La Vista In Borivali East ',
#  '1 BHK In Independent House  For Sale  In Dahisar East ',
#  '1 BHK Flat  For Sale  In Shiv Sai Chs In Borivali East ',
#  '1 BHK Flat  For Sale  In Raigad Chs, Borivali In Raigad Chs Ltd ',
#  '1 BHK Flat  For Sale  In Raigad Chs In Dahisar East ',
#  '1 RK Flat  For Sale  In Dahisar Sanmitra In  Borivali East ',
#  '2 BHK Flat  For Sale  In La-bellezza In Borivali East ',
#  '1 BHK Flat  For Sale  In Chandresh Deep Cooperative Housing Society ',
#  '1 BHK Apartment  For Sale  In Gautam Chs In Borivali East ',
#  '2 BHK Flat  For Sale  In Morya Avenue In Borivali East ',
#  '1 BHK Flat  For Sale  In Morya Avenue In Borivali East ',
#  '2 BHK Flat  For Sale  In Morya Avenue In Borivali East ',
#  '1 BHK Flat  For Sale  In Gopi-ka-ram Society In Sant Dnyaneshwar Road, Borivali East ',
#  '1 BHK Flat  For Sale  In Green View Complex  In Borivali East ',
# ...

# %%
location = []
for i in soup.find_all('div', class_='nb__1EwQz'):
  location.append(i.text)

location
# Out:
# ['La Vista Shop 4, Rishivan, Om Siddhivinayak Society, Kajupada, Borivali East, Mumbai, Maharashtra 400066, India',
#  'Near Abhinav Nagar, Borivali East, Mumbai, Maharashtra, INDIA.',
#  'Independent House, hanuman tedki near saibaba mandir kajupada',
#  'B-101, Borivali East, Mumbai, Maharashtra 400066, India',
#  'Shiv vallabh rd',
#  'Raigad CHS, Ashok Van, Shiv Vallabh Road, Dahisar (E), Maharashtra 400066, India',
#  'Universal High School, Ashok Van, ',
#  'Rishivan, Next to Sant Gadge Maharaj Marg, Kajupada, Borivali East Mumbai, Maharashtra 400066 India',
#  'sant dyaneshwar road',
#  'Gautam Chs\xa0 Kajupada, Near Om Siddharaj CHS',
#  'Chogle Nagar, Behind shani mandir, Borivali East, Mumbai, Maharashtra 400066, India',
#  'Chogle Nagar behind shani mandir,',
#  'Chogle Nagar, Behind shani mandir, Borivali East, Mumbai, Maharashtra 400066, India',
#  'Sawarkar Nagar, Sant Dnyaneshwar marg, Borivali East',
#  'Nency colony',
# ...

# %%
area = []
for i in soup.find_all('div', class_='nb__FfHqA'):
  area.append(i.text)
area
# Out:
# ['1,690 sqft',
#  '1,110 sqft',
#  '300 sqft',
#  '455 sqft',
#  '525 sqft',
#  '460 sqft',
#  '330 sqft',
#  '915 sqft',
#  '400 sqft',
#  '510 sqft',
#  '750 sqft',
#  '550 sqft',
#  '975 sqft',
#  '515 sqft',
#  '550 sqft',
#  '585 sqft',
#  '512 sqft',
#  '720 sqft',
#  '580 sqft',
#  '1,100 sqft',
#  '400 sqft',
#  '225 sqft',
#  '350 sqft',
#  '1,900 sqft',
#  '710 sqft']

# %%
emi_2 = []
#d = font-semi-bold heading-6
#c = "font-semi-bold heading-6"
for i in soup.find_all('div', class_='font-semi-bold heading-6'):
  emi_2.append(i.text.split('\n')[0])
emi_2
# Out:
# ['1,690 sqft',
#  'â\x82¹1.23 Lacs/Month',
#  'â\x82¹2.15 Crores',
#  '1,110 sqft',
#  'â\x82¹1.03 Lacs/Month',
#  'â\x82¹1.8 Crores',
#  '300 sqft',
#  'â\x82¹14,328/Month',
#  'â\x82¹25 Lacs',
#  '455 sqft',
#  'â\x82¹42,985/Month',
#  'â\x82¹75 Lacs',
#  '525 sqft',
#  'â\x82¹41,266/Month',
#  'â\x82¹72 Lacs',
#  '460 sqft',
#  'â\x82¹44,132/Month',
#  'â\x82¹77 Lacs',
#  '330 sqft',
#  'â\x82¹28,657/Month',
#  'â\x82¹50 Lacs',
#  '915 sqft',
#  'â\x82¹71,643/Month',
#  'â\x82¹1.25 Crores',
#  '400 sqft',
#  'â\x82¹41,266/Month',
#  'â\x82¹72 Lacs',
#  '510 sqft',
#  'â\x82¹45,851/Month',
#  'â\x82¹80 Lacs',
#  '750 sqft',
#  'â\x82¹77,374/Month',
#  'â\x82¹1.35 Crores',
#  '550 sqft',
#  'â\x82¹54,448/Month',
#  'â\x82¹95 Lacs',
#  '975 sqft',
#  'â\x82¹79,093/Month',
#  'â\x82¹1.38 Crores',
#  '515 sqft',
#  'â\x82¹48,717/Month',
#  'â\x82¹85 Lacs',
#  '550 sqft',
#  'â\x82¹55,021/Month',
#  'â\x82¹96 Lacs',
#  '585 sqft',
#  'â\x82¹57,314/Month',
#  'â\x82¹1 Crore',
# ...

# %%
reduced_emi = []
for x in actual_emi:
    reduced_emi.append(x.replace("â\x82¹", ""))
reduced_emi
print(len(reduced_emi), reduced_emi)
# Out:
# 25 ['1.23 Lacs/Month', '1.03 Lacs/Month', '14,328/Month', '42,985/Month', '41,266/Month', '44,132/Month', '28,657/Month', '71,643/Month', '41,266/Month', '45,851/Month', '77,374/Month', '54,448/Month', '79,093/Month', '48,717/Month', '55,021/Month', '57,314/Month', '40,693/Month', '25,791/Month', '53,302/Month', '1 Lacs/Month', '22,925/Month', '16,621/Month', '22,925/Month', '1.89 Lacs/Month', '85,971/Month']

# %%
reduced_emi = []
for x in actual_emi:
    reduced_emi.append(x.replace("â\x82¹", ""))
reduced_emi
print(len(reduced_emi), reduced_emi)
# Out:
# 25 ['1.23 Lacs/Month', '1.03 Lacs/Month', '14,328/Month', '42,985/Month', '41,266/Month', '44,132/Month', '28,657/Month', '71,643/Month', '41,266/Month', '45,851/Month', '77,374/Month', '54,448/Month', '79,093/Month', '48,717/Month', '55,021/Month', '57,314/Month', '40,693/Month', '25,791/Month', '53,302/Month', '1 Lacs/Month', '22,925/Month', '16,621/Month', '22,925/Month', '1.89 Lacs/Month', '85,971/Month']

# %%
actual_prices = []
for x in prices:
    actual_prices.append(x.replace("â\x82¹", ""))
actual_prices
# Out:
# ['2.15 Crores',
#  '1.8 Crores',
#  '25 Lacs',
#  '75 Lacs',
#  '72 Lacs',
#  '77 Lacs',
#  '50 Lacs',
#  '1.25 Crores',
#  '72 Lacs',
#  '80 Lacs',
#  '1.35 Crores',
#  '95 Lacs',
#  '1.38 Crores',
#  '85 Lacs',
#  '96 Lacs',
#  '1 Crore',
#  '71 Lacs',
#  '45 Lacs',
#  '93 Lacs',
#  '1.75 Crores',
#  '40 Lacs',
#  '29 Lacs',
#  '40 Lacs',
#  '3.3 Crores',
#  '1.5 Crores']

# %%
print(len(names), len(location) , len(actual_prices), len(reduced_emi), len(area))
# Out:
# 25 25 25 25 25

# %%
import pandas as pd
df = pd.DataFrame({'Name':names,'Location':location,'Prices': actual_prices,'EMI':reduced_emi})
#names location actual_prices emi_2
df
# Out:
#                                                  Name  \
# 0   3 BHK Flat  For Sale  In La Vista In Borivali ...
# 1   2 BHK Flat  For Sale  In Dimple La Vista In Bo...
# 2   1 BHK In Independent House  For Sale  In Dahis...
# 3   1 BHK Flat  For Sale  In Shiv Sai Chs In Boriv...
# 4   1 BHK Flat  For Sale  In Raigad Chs, Borivali ...
# 5   1 BHK Flat  For Sale  In Raigad Chs In Dahisar...
# 6   1 RK Flat  For Sale  In Dahisar Sanmitra In  B...
# 7   2 BHK Flat  For Sale  In La-bellezza In Boriva...
# 8   1 BHK Flat  For Sale  In Chandresh Deep Cooper...
# 9   1 BHK Apartment  For Sale  In Gautam Chs In Bo...
# 10  2 BHK Flat  For Sale  In Morya Avenue In Boriv...
# 11  1 BHK Flat  For Sale  In Morya Avenue In Boriv...
# 12  2 BHK Flat  For Sale  In Morya Avenue In Boriv...
# 13  1 BHK Flat  For Sale  In Gopi-ka-ram Society I...
# 14  1 BHK Flat  For Sale  In Green View Complex  I...
# 15  1 BHK Flat  For Sale  In Green View Complex In...
# ...
